# %%
# 1. import libraries
import requests # to download html code
from bs4 import BeautifulSoup # to navigate through the html code
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.billboard.com/charts/hot-100/"

# %%
# 3. download html with a get request. Use the function request.get() and store the output in response
response = requests.get(url)
# 200 status code means OK! response.status_code
print(response.status_code)
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.text, 'html.parser')
# 4.2. check that the html code looks like it should
#print(soup.prettify())

# %%
#lets try to get the 1st title

soup.select('li>h3')[0].get_text().strip()
# Out:
# 'Flowers'

# %%
#lets have a look at this class

soup.select('li>span')
# Out:
# [<span class="c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Miley Cyrus
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	3
#  </span>,
# ...

# %%
#lets get the 1st artist

soup.select('li > span.c-label.a-no-trucate')[0].get_text().strip()
# Out:
# 'Miley Cyrus'

# %%
#time to create a list of the top 100 songs

top_100_songs=[]

for elem in range(100):
    top_100_songs.append(soup.select('li>h3')[elem].get_text().strip())

# %%
#same thing for the artists

top_100_artists=[]

for elem in range(100):
    top_100_artists.append(soup.select('li > span.c-label.a-no-trucate')[elem].get_text().strip())

# %%
#lets create the dataframe with artist and their respective song

top_100_df = pd.DataFrame({'artist': top_100_artists, 'song': top_100_songs})

# %%
top_100_df
# Out:
#                                   artist                         song
# 0                            Miley Cyrus                      Flowers
# 1                                    SZA                    Kill Bill
# 2   Metro Boomin, The Weeknd & 21 Savage                     Creepin'
# 3                           Taylor Swift                    Anti-Hero
# 4                 Sam Smith & Kim Petras                       Unholy
# ..                                   ...                          ...
# 95                  Ozuna Featuring Feid                      Hey Mor
# 96                Nengo Flow & Bad Bunny                Gato de Noche
# 97                           Mac DeMarco               Heart To Heart
# 98                                  P!nk  Never Gonna Not Dance Again
# 99                         Tyler Hubbard       Dancin' In The Country
#
# [100 rows x 2 columns]
